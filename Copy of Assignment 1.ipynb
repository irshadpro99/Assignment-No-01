# %%
#firstprogram.py
print ("Hello World!")
# Out:
# Hello World!

# %%
print("I am a student of Meta learn")
# Out:
# I am a student of Meta learn

# %%
print("I am now starting to learn basic python course")
# Out:
# I am now starting to learn basic python course

# %%
print("My name is Muhammad Irshad")
# Out:
# My name is Muhammad Irshad

# %%
print("I am very happy after Join Meta learn platform")
# Out:
# I am very happy after Join Meta learn platform

# %%
print("May Allah succeeded me in this Journey")
# Out:
# May Allah succeeded me in this Journey
